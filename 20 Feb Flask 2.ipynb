# %% [markdown]
# Q1. Explain GET and POST methods.

# %% [markdown]
# GET :
# GET method is used to appends form data to the URL in name or value pair. If we use GET, the length of URL will remain limited. It helps users to submit the bookmark the result. GET is better for the data which does not require any security or having images or word documents.
#
#     Example: http://RegisterStudent.html?user=value1&pass=value2
#
# Features of GET
# 1. It is very easy to bookmark data using GET method.
# 2. The length restriction of GET method is limited.
# 3. You can use this method only to retrieve data from the address bar in the browser.
# 4. This method enables you to easily store the data.
#
# POST :
# POST is a method that is supported by HTTP and depicts that a web server accepts the data included in the body of the message. POST is often used by World Wide Web to send user generated data to the web server or when you upload file.
#
#     Example : POST/RegisterStudent.html HTTP/1.1
#                 Host: www.student.com
#                 user=value1&pass=value2
#
# Features of POST
# 1. POST method request gets input from the request body and query string.
# 2. Data passed using the POST method will not visible in query parameters in browser URL.
# 3. parameters of POST methods are not saved in browser history.
# 4. There is no restriction in sending the length of data.
# 5. It helps you to securely pass sensitive and confidential information like login details to server.

# %% [markdown]
# Q2. Why is request used in Flask?

# %% [markdown]
# The Request, in Flask, is an object that contains all the data sent from the Client to Server. This data can be recovered using the GET/POST Methods. POST is used when your application expects user input to be received by command or an HTTP request, while GET gets all the information before it even has a chance for submission.
#
# There are various attributes associated with the request objects. They are Form, Cookies, Args, Files, and Method.
#
# 1. The form is used to create and return the form data from other application codes like JSP API or POST. This attribute    allows you to specify predefined custom parameters when creating HTTP requests for your service (like “GET /info” )      which can be given as string values without any format validation etc.
# 2. The cookies property contains cookie contents that will allow the client to access a piece of information about users’    details through the Cookie header field of returned JSON Object Content Type Information.
# 3. Args is used to initialize a Request constructor which you have given as a parameter of the class.
# 4. The method is used to create a new form element or an existing one via custom URL configuration.

# %% [markdown]
# Q3. Why is redirect() used in Flask?

# %% [markdown]
# Flask redirect is defined as a function or utility in Flask which allows developers to redirect users to a specified URL and assign a specified status code. When this function is called, a response object is returned, and the redirection happens to the target location with the status code. When a website is visited, server receives a request and after processing responds to the request with a three-digit code known as the HTTP code. In a programming world this status code that is returned as a response is known as Errors.
#
# 1. Importing the redirect function.
#      from flask import redirect, abort
# 2. Instantiating of Flask redirect.
#     flask.redirect(<location>,<status-code>, <response> )
# Here,
# <location>: Denotes the URL location to which the response from the redirect will be routed to.
# <status-code>: Represents the status code which is sent to the header of the browser besides the response from the                      server.
# <response>: For any future references or requirements of the project, this is the instance that is referred to.
#
#         Example:
#                 from flask import Flask, redirect, url_for
#
#                 appFlask = Flask(__name__)
#
#                 @appFlask.route("/home")
#                 def home():
#                 return redirect(url_for('LoginPage'))
#
#                 @appFlask.route("/LoginPage")
#                 def LoginPage():
#                 return "You are redirected to Login Page"
#
#                 if __name__ == "__main__":
#                     app.run(host="0.0.0.0")

# %% [markdown]
# Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# Templates are files that contain static data as well as placeholders for dynamic data. A template is rendered with specific data to produce a final document. Flask uses the Jinja template library to render templates. In our application, we are using templates to render HTML which will display in the user’s browser.
#
# Why is the render_template() function used?
#
# render_template is a Flask function from the flask.templating package. render_template is used to generate output from a template file based on the Jinja2 engine that is found in the application's templates folder.
#
#     Example:
#             from flask import Flask, render_template
#             app = Flask(__name__)
#
#             @app.route("/")
#             def index():
#                 pagetitle = "HomePage"
#                 return render_template("index.html", mytitle=pagetitle)
#
#             if __name__ == "__main__":
#              app.run(host="0.0.0.0")

# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# Simple API :
# ==================

# %% [raw]
# index.html
# _________________
#
# {% block head %}
#
# <title>Full Name</title>
# <link rel="stylesheet" href="{{ url_for('static', filename='css/style.css') }}">
# {% endblock %}
#
# {% block body %}
# <div class="content">
#     <h1 style="text-align: center">Join to make full Name</h1>
#
#     <div class="form">
#         <form action="/add_name" method="POST">
# </select>
#             <input type="text" name="first_name" id="first_name">
#             <input type="text" name="last_name" id="last_name">
#             <input type="submit" value="Full Name">
#         </form>
#     </div>
# </div>
# {% endblock %}
#
#
# results.html
# _______________________
#
# <!DOCTYPE html>
# <html lang="en" >
#
# <head>
#   <meta charset="UTF-8">
#   <title>Review Page</title>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/normalize/5.0.0/normalize.min.css">
#       <link rel="stylesheet" href="./style.css">
#     <link rel="stylesheet" href="{{ url_for('static', filename='css/style.css') }}">
# </head>
# <body>
#   <div class="table-users">
#    <div class="header">Concatenation Result</div>
#
#       {{result}}
# </div>
# </body>
# </html>
#
#
# app.py
# _____________________
# from flask import Flask, request, render_template
#
# app = Flask(__name__)
#
#
# @app.route('/')
# def home_page():
#     return render_template('index.html')
#
# @app.route('/add_name',methods=['POST'])
# def ops1():
#     if(request.method == 'POST'):
#         first_name = request.form['first_name']
#         last_name = request.form['last_name']
#         rslt = first_name +" "+ last_name
#         result = "The full Name of " +first_name+ '  and ' +last_name + "  is " + rslt
#
#         return render_template('results.html' , result = result)
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")

# %% [markdown]
# Simple API output :-
#
# ![Screenshot (11).png](attachment:e635f305-13bf-409c-bba8-edef26c40f60.png)![Screenshot (12).png](attachment:67f442e6-0507-4e18-9fb7-6c4ddbce8046.png)
#
# By Using Postman :-
# =======================
#
# app.py
# ______________
#
# from flask import Flask,request ,render_template , jsonify
# app = Flask(__name__)
#
# @app.route('/')
# def home_page():
#     return render_template('index.html')
#
# @app.route('/postman',methods=['POST'])
# def ops1():
#     if(request.method == 'POST'):
#         first_name = request.json['first_name']
#         last_name = request.json['last_name']
#         rslt = first_name +" "+ last_name
#         result = "The full Name of " +first_name+ '  and ' +last_name + "  is " + rslt
#
#         return jsonify(result)
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")
#
# OUTPUT OF POSTMAN :-
#
# ![Screenshot (13).png](attachment:6f4dac8e-1951-42b6-ba16-2bfc7033e82d.png)
